# %%
import rickpy
rickpy.use_dev_packages(['rickpy','scidash/sciunit','scidash/neuronunit','neuroml/pyNeuroML'])
import imp
imp.reload(rickpy);

# %%
# %matplotlib notebook
import os,sys
import numpy as np
import matplotlib.pyplot as plt
import quantities as pq
import sciunit
import neuronunit
from neuronunit import aibs
from neuronunit.models.reduced import ReducedModel
from allensdk.api.queries.cell_types_api import CellTypesApi

# %%
# Replace this with your model path.  
# This example is from https://github.com/OpenSourceBrain/IzhikevichModel.
PWD = os.path.expanduser(os.getcwd())#updated this repository such that the file lives in current directory
#in order to facilitate file notebook reproducibility.
LEMS_MODEL_PATH = os.path.join(PWD,'LEMS_2007One.xml')

# %%
#vm is not initialized so the code will not run:
#from neuronunit.capabilities import spike_functions
#does the variable vm come from a personal dropbox account?
#waveforms = spike_functions.get_spike_waveforms(vm)
#np.max(waveforms.data,axis=1)

# %%
#np.max(np.array(waveforms),axis=1)

# %%
#np.max(waveforms,axis=1)
# Out:
# ['CellTypesApi', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'get_observation', 'get_sp', 'get_square_stim_characteristics', 'get_sweep_from_nwb', 'get_sweep_params', 'get_value_dict', 'np', 'pq']

# %%
import quantities as pq
from neuronunit import tests as nu_tests, neuroelectro
neuron = {'nlex_id': 'nifext_50'} # Layer V pyramidal cell
tests = []

dataset_id = 354190013  # Internal ID that AIBS uses for a particular Scnn1a-Tg2-Cre 
                        # Primary visual area, layer 5 neuron.

ct = CellTypesApi()    
experiment_params = ct.get_ephys_sweeps(dataset_id)
cmd = ct.get_ephys_features(dataset_id)
sweep_ids=cmd['rheobase_sweep_id'] #Retrieva all of the sweeps corresponding to finding rheobase.
#warning although this patch makes the code execute, it does not mean tha the current function of the code is logical. 
observation = aibs.get_value_dict(experiment_params,sweep_ids, kind = str('rheobase'))  
#observation = aibs.get_observation(dataset_id,'rheobase')

tests += [nu_tests.RheobaseTest(observation=observation)]
    
test_class_params = [(nu_tests.InputResistanceTest,None),
                     (nu_tests.TimeConstantTest,None),
                     (nu_tests.CapacitanceTest,None),
                     (nu_tests.RestingPotentialTest,None),
                     (nu_tests.InjectedCurrentAPWidthTest,None),
                     (nu_tests.InjectedCurrentAPAmplitudeTest,None),
                     (nu_tests.InjectedCurrentAPThresholdTest,None)]

for cls,params in test_class_params:
    observation = cls.neuroelectro_summary_observation(neuron)
    tests += [cls(observation,params=params)]
    
def update_amplitude(test,tests,score):
    rheobase = score.prediction['value']
    for i in [3,4,5]:
        tests[i].params['injected_square_current']['amplitude'] = rheobase*1.01 # Set current injection to just suprathreshold
    
hooks = {tests[0]:{'f':update_amplitude}}
suite = sciunit.TestSuite("vm_suite",tests,hooks=hooks)
# Out:
# Getting data values from neuroelectro.org
# http://www.neuroelectro.org/api/1/nes/?nlex=nifext_50&e__name=Input+Resistance
# Getting data values from neuroelectro.org
# http://www.neuroelectro.org/api/1/nes/?nlex=nifext_50&e__name=Membrane+Time+Constant
# Getting data values from neuroelectro.org
# http://www.neuroelectro.org/api/1/nes/?nlex=nifext_50&e__name=Cell+Capacitance
# Getting data values from neuroelectro.org
# http://www.neuroelectro.org/api/1/nes/?nlex=nifext_50&e__name=Resting+membrane+potential
# Getting data values from neuroelectro.org
# http://www.neuroelectro.org/api/1/nes/?nlex=nifext_50&e__name=Spike+Half-Width
# Getting data values from neuroelectro.org
# http://www.neuroelectro.org/api/1/nes/?nlex=nifext_50&e__name=Spike+Amplitude
# Getting data values from neuroelectro.org
# http://www.neuroelectro.org/api/1/nes/?nlex=nifext_50&e__name=Spike+Threshold

# %%
model = ReducedModel(LEMS_MODEL_PATH,name='vanilla')
suite.judge(model)
# Out:
# Executing test <i>RheobaseTest</i> on model <i>vanilla</i>...
# pyNeuroML >>> Executing: (java -Xmx400M  -Djava.awt.headless=true -jar  "/opt/conda/lib/python3.5/site-packages/pyneuroml/lib/jNeuroML-0.8.0-jar-with-dependencies.jar"  "/tmp/vanilla.xml"  -neuron -run -nogui) in directory: .
# pyNeuroML >>> Command completed. Output:
# pyNeuroML >>>   jNeuroML >>   jNeuroML v0.8.0
# pyNeuroML >>>   jNeuroML >>  (INFO) Reading from: /tmp/vanilla.xml
# pyNeuroML >>>   jNeuroML >>  (INFO) Creating NeuronWriter for vanilla_nrn.py
# pyNeuroML >>>   jNeuroML >>  (INFO) Adding simulation Component(id=sim1 type=Simulation) of network/component: net1 (Type: network)
# pyNeuroML >>>   jNeuroML >>  (INFO) Adding population: RS_pop
# pyNeuroML >>>   jNeuroML >>  (INFO) -- Writing to mod: /tmp/RS.mod
# pyNeuroML >>>   jNeuroML >>  (INFO) Adding projections/connections...
# pyNeuroML >>>   jNeuroML >>  (INFO) -- Writing to mod: /tmp/RS_Iext.mod
# pyNeuroML >>>   jNeuroML >>  (INFO) Trying to compile mods in: /tmp
# pyNeuroML >>>   jNeuroML >>  (INFO) Going to compile the mod files in: /tmp, forcing recompile: false
# pyNeuroML >>>   jNeuroML >>  (INFO) Parent dir: /tmp
# pyNeuroML >>>   jNeuroML >>  (INFO) Assuming *nix environment...
# pyNeuroML >>>   jNeuroML >>  (INFO) Name of file to be created: /tmp/x86_64/libnrnmech.la
# pyNeuroML >>>   jNeuroML >>  (INFO) Backup file to check for success: /tmp/x86_64/libnrnmech.la
# pyNeuroML >>>   jNeuroML >>  (INFO) commandToExecute: /home/jovyan/neuron/nrn-7.4/x86_64/bin/nrnivmodl
# pyNeuroML >>>   jNeuroML >>  (INFO) Going to check if mods in /tmp are newer than null
# pyNeuroML >>>   jNeuroML >>  (INFO) Trying to delete any previous: /tmp/x86_64/libnrnmech.la
# pyNeuroML >>>   jNeuroML >>  (INFO) directoryToExecuteIn: /tmp
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Compile >> > Creating x86_64 directory for .o files.
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Compile >> >
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Compile >> > /tmp
# pyNeuroML >>>   jNeuroML >>  (INFO) Have successfully executed command: /home/jovyan/neuron/nrn-7.4/x86_64/bin/nrnivmodl
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Compile >> > RS.mod RS_Iext.mod
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Compile >> > RS.mod RS_Iext.mod
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Compile >> > "/home/jovyan/neuron/nrn-7.4/x86_64/bin/nocmodl" RS
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Error   >> > Translating RS.mod into RS.c
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Error   >> > Thread Safe
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Compile >> > "/home/jovyan/neuron/nrn-7.4/share/nrn/libtool"  --mode=compile gcc -DHAVE_CONFIG_H  -I. -I.. -I"/home/jovyan/neuron/nrn-7.4/include/nrn" -I"/home/jovyan/neuron/nrn-7.4/x86_64/lib"      -g -O2 -c -o RS.lo RS.c
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Compile >> > libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I.. -I/home/jovyan/neuron/nrn-7.4/include/nrn -I/home/jovyan/neuron/nrn-7.4/x86_64/lib -g -O2 -c RS.c  -fPIC -DPIC -o .libs/RS.o
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Compile >> > "/home/jovyan/neuron/nrn-7.4/x86_64/bin/nocmodl" RS_Iext
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Error   >> > Translating RS_Iext.mod into RS_Iext.c
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Error   >> > Thread Safe
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Compile >> > "/home/jovyan/neuron/nrn-7.4/share/nrn/libtool"  --mode=compile gcc -DHAVE_CONFIG_H  -I. -I.. -I"/home/jovyan/neuron/nrn-7.4/include/nrn" -I"/home/jovyan/neuron/nrn-7.4/x86_64/lib"      -g -O2 -c -o RS_Iext.lo RS_Iext.c
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Compile >> > libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I.. -I/home/jovyan/neuron/nrn-7.4/include/nrn -I/home/jovyan/neuron/nrn-7.4/x86_64/lib -g -O2 -c RS_Iext.c  -fPIC -DPIC -o .libs/RS_Iext.o
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Compile >> > "/home/jovyan/neuron/nrn-7.4/share/nrn/libtool"  --mode=compile gcc -DHAVE_CONFIG_H  -I. -I.. -I"/home/jovyan/neuron/nrn-7.4/include/nrn" -I"/home/jovyan/neuron/nrn-7.4/x86_64/lib"      -g -O2 -c -o mod_func.lo mod_func.c
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Compile >> > libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I.. -I/home/jovyan/neuron/nrn-7.4/include/nrn -I/home/jovyan/neuron/nrn-7.4/x86_64/lib -g -O2 -c mod_func.c  -fPIC -DPIC -o .libs/mod_func.o
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Compile >> > "/home/jovyan/neuron/nrn-7.4/share/nrn/libtool"  --mode=link gcc -module  -g -O2    -o libnrnmech.la -rpath "/home/jovyan/neuron/nrn-7.4/x86_64/lib"  RS.lo RS_Iext.lo mod_func.lo  -L"/home/jovyan/neuron/nrn-7.4/x86_64/lib" -lnrnoc -loc -lmemacs -lnrnmpi -lscopmath -lsparse13 -lreadline -lncurses -L"/home/jovyan/neuron/nrn-7.4/x86_64/lib" "/home/jovyan/neuron/nrn-7.4/x86_64/lib/libnrniv.la" -livoc -lneuron_gnu -lmeschach -lsundials -livos      -lm -ldl
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Compile >> > libtool: link: gcc -shared  -fPIC -DPIC  .libs/RS.o .libs/RS_Iext.o .libs/mod_func.o   -Wl,-rpath -Wl,/home/jovyan/neuron/nrn-7.4/x86_64/lib -Wl,-rpath -Wl,/home/jovyan/neuron/nrn-7.4/x86_64/lib -L/home/jovyan/neuron/nrn-7.4/x86_64/lib /home/jovyan/neuron/nrn-7.4/x86_64/lib/libnrnoc.so /home/jovyan/neuron/nrn-7.4/x86_64/lib/liboc.so /home/jovyan/neuron/nrn-7.4/x86_64/lib/libmemacs.so /home/jovyan/neuron/nrn-7.4/x86_64/lib/libnrnmpi.so /home/jovyan/neuron/nrn-7.4/x86_64/lib/libscopmath.so /home/jovyan/neuron/nrn-7.4/x86_64/lib/libsparse13.so -lreadline -lncurses /home/jovyan/neuron/nrn-7.4/x86_64/lib/libnrniv.so /home/jovyan/neuron/nrn-7.4/x86_64/lib/libivoc.so /home/jovyan/neuron/nrn-7.4/x86_64/lib/libneuron_gnu.so /home/jovyan/neuron/nrn-7.4/x86_64/lib/libmeschach.so /home/jovyan/neuron/nrn-7.4/x86_64/lib/libsundials.so /home/jovyan/neuron/nrn-7.4/x86_64/lib/libivos.so -lm -ldl  -O2   -pthread -Wl,-soname -Wl,libnrnmech.so.0 -o .libs/libnrnmech.so.0.0.0
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Compile >> > libtool: link: (cd ".libs" && rm -f "libnrnmech.so.0" && ln -s "libnrnmech.so.0.0.0" "libnrnmech.so.0")
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Compile >> > libtool: link: (cd ".libs" && rm -f "libnrnmech.so" && ln -s "libnrnmech.so.0.0.0" "libnrnmech.so")
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Compile >> > libtool: link: ( cd ".libs" && rm -f "libnrnmech.la" && ln -s "../libnrnmech.la" "libnrnmech.la" )
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Compile >> > Successfully created x86_64/special
# pyNeuroML >>>   jNeuroML >>  (INFO) Successful compilation
# pyNeuroML >>>   jNeuroML >>  (INFO) Success: true
# pyNeuroML >>>   jNeuroML >>  (INFO) Have successfully executed command: /home/jovyan/neuron/nrn-7.4/x86_64/bin/nrniv -python /tmp/vanilla_nrn.py
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Error  >>> NEURON -- Release 7.4 (1370:16a7055d4a86) 2015-11-09
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Error  >>> Duke, Yale, and the BlueBrain Project -- Copyright 1984-2015
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Error  >>> See http://www.neuron.yale.edu/neuron/credits
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Error  >>>
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Error  >>> Additional mechanisms from files
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Error  >>>  RS.mod RS_Iext.mod
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Output >>>
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Output >>>     Starting simulation in NEURON generated from NeuroML2 model...
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Output >>>
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Output >>> Population RS_pop contains 1 instance(s) of component: RS of type: izhikevich2007Cell
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Output >>> Running a simulation of 520.0ms (dt = 0.001ms)
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Output >>> Finished NEURON simulation in 0.744370 seconds (0.012406 mins)...
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Output >>> Saving results at t=519.9999999911596...
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Output >>> Saved data to: time.dat
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Output >>> Saved data to: exIzh.dat
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Output >>> Finished saving results in 1.068982 seconds
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Output >>> Done
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Output >>> first instance of n_RS_pop
# pyNeuroML >>>   jNeuroML >>  (INFO) Exit value for running NEURON: 0
# pyNeuroML >>>   jNeuroML >>
# t
# RS_pop[0]/v
# [-0.06       -0.05999913 -0.05999913 ..., -0.06       -0.06       -0.06      ] V
# Injected 0.0 pA current and got 0 spikes
# pyNeuroML >>> Executing: (java -Xmx400M  -Djava.awt.headless=true -jar  "/opt/conda/lib/python3.5/site-packages/pyneuroml/lib/jNeuroML-0.8.0-jar-with-dependencies.jar"  "/tmp/vanilla.xml"  -neuron -run -nogui) in directory: .
# pyNeuroML >>> Command completed. Output:
# pyNeuroML >>>   jNeuroML >>   jNeuroML v0.8.0
# pyNeuroML >>>   jNeuroML >>  (INFO) Reading from: /tmp/vanilla.xml
# pyNeuroML >>>   jNeuroML >>  (INFO) Creating NeuronWriter for vanilla_nrn.py
# pyNeuroML >>>   jNeuroML >>  (INFO) Adding simulation Component(id=sim1 type=Simulation) of network/component: net1 (Type: network)
# pyNeuroML >>>   jNeuroML >>  (INFO) Adding population: RS_pop
# pyNeuroML >>>   jNeuroML >>  (INFO) -- Writing to mod: /tmp/RS.mod
# pyNeuroML >>>   jNeuroML >>  (INFO) File /tmp/RS.mod exists and is identical
# pyNeuroML >>>   jNeuroML >>  (INFO) Adding projections/connections...
# pyNeuroML >>>   jNeuroML >>  (INFO) -- Writing to mod: /tmp/RS_Iext.mod
# pyNeuroML >>>   jNeuroML >>  (INFO) File /tmp/RS_Iext.mod exists but is different
# pyNeuroML >>>   jNeuroML >>  (INFO) Trying to compile mods in: /tmp
# pyNeuroML >>>   jNeuroML >>  (INFO) Going to compile the mod files in: /tmp, forcing recompile: false
# pyNeuroML >>>   jNeuroML >>  (INFO) Parent dir: /tmp
# pyNeuroML >>>   jNeuroML >>  (INFO) Assuming *nix environment...
# pyNeuroML >>>   jNeuroML >>  (INFO) Name of file to be created: /tmp/x86_64/libnrnmech.la
# pyNeuroML >>>   jNeuroML >>  (INFO) Backup file to check for success: /tmp/x86_64/libnrnmech.la
# pyNeuroML >>>   jNeuroML >>  (INFO) commandToExecute: /home/jovyan/neuron/nrn-7.4/x86_64/bin/nrnivmodl
# pyNeuroML >>>   jNeuroML >>  (INFO) Going to check if mods in /tmp are newer than /tmp/x86_64/libnrnmech.la
# pyNeuroML >>>   jNeuroML >>  (INFO) File /tmp/RS_Iext.mod (November 29, 2016 1:27:57 AM UTC) was modified later than /tmp/x86_64/libnrnmech.la (November 29, 2016 1:27:54 AM UTC)
# pyNeuroML >>>   jNeuroML >>  (INFO) Newer mod files exist!
# pyNeuroML >>>   jNeuroML >>  (INFO) Trying to delete any previous: /tmp/x86_64/libnrnmech.la
# pyNeuroML >>>   jNeuroML >>  (INFO) Deleted.
# pyNeuroML >>>   jNeuroML >>  (INFO) directoryToExecuteIn: /tmp
# pyNeuroML >>>   jNeuroML >>  (INFO) Have successfully executed command: /home/jovyan/neuron/nrn-7.4/x86_64/bin/nrnivmodl
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Compile >> > /tmp
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Compile >> > RS.mod RS_Iext.mod
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Compile >> > RS.mod RS_Iext.mod
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Compile >> > "/home/jovyan/neuron/nrn-7.4/x86_64/bin/nocmodl" RS_Iext
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Error   >> > Translating RS_Iext.mod into RS_Iext.c
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Error   >> > Thread Safe
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Compile >> > "/home/jovyan/neuron/nrn-7.4/share/nrn/libtool"  --mode=compile gcc -DHAVE_CONFIG_H  -I. -I.. -I"/home/jovyan/neuron/nrn-7.4/include/nrn" -I"/home/jovyan/neuron/nrn-7.4/x86_64/lib"      -g -O2 -c -o RS_Iext.lo `test -f 'RS_Iext.c' || echo '/'`RS_Iext.c
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Compile >> > libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I.. -I/home/jovyan/neuron/nrn-7.4/include/nrn -I/home/jovyan/neuron/nrn-7.4/x86_64/lib -g -O2 -c RS_Iext.c  -fPIC -DPIC -o .libs/RS_Iext.o
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Compile >> > "/home/jovyan/neuron/nrn-7.4/share/nrn/libtool"  --mode=compile gcc -DHAVE_CONFIG_H  -I. -I.. -I"/home/jovyan/neuron/nrn-7.4/include/nrn" -I"/home/jovyan/neuron/nrn-7.4/x86_64/lib"      -g -O2 -c -o mod_func.lo mod_func.c
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Compile >> > libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I.. -I/home/jovyan/neuron/nrn-7.4/include/nrn -I/home/jovyan/neuron/nrn-7.4/x86_64/lib -g -O2 -c mod_func.c  -fPIC -DPIC -o .libs/mod_func.o
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Compile >> > "/home/jovyan/neuron/nrn-7.4/share/nrn/libtool"  --mode=link gcc -module  -g -O2    -o libnrnmech.la -rpath "/home/jovyan/neuron/nrn-7.4/x86_64/lib"  RS.lo RS_Iext.lo mod_func.lo  -L"/home/jovyan/neuron/nrn-7.4/x86_64/lib" -lnrnoc -loc -lmemacs -lnrnmpi -lscopmath -lsparse13 -lreadline -lncurses -L"/home/jovyan/neuron/nrn-7.4/x86_64/lib" "/home/jovyan/neuron/nrn-7.4/x86_64/lib/libnrniv.la" -livoc -lneuron_gnu -lmeschach -lsundials -livos      -lm -ldl
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Compile >> > libtool: link: rm -fr  .libs/libnrnmech.la .libs/libnrnmech.lai .libs/libnrnmech.so .libs/libnrnmech.so.0 .libs/libnrnmech.so.0.0.0
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Compile >> > libtool: link: gcc -shared  -fPIC -DPIC  .libs/RS.o .libs/RS_Iext.o .libs/mod_func.o   -Wl,-rpath -Wl,/home/jovyan/neuron/nrn-7.4/x86_64/lib -Wl,-rpath -Wl,/home/jovyan/neuron/nrn-7.4/x86_64/lib -L/home/jovyan/neuron/nrn-7.4/x86_64/lib /home/jovyan/neuron/nrn-7.4/x86_64/lib/libnrnoc.so /home/jovyan/neuron/nrn-7.4/x86_64/lib/liboc.so /home/jovyan/neuron/nrn-7.4/x86_64/lib/libmemacs.so /home/jovyan/neuron/nrn-7.4/x86_64/lib/libnrnmpi.so /home/jovyan/neuron/nrn-7.4/x86_64/lib/libscopmath.so /home/jovyan/neuron/nrn-7.4/x86_64/lib/libsparse13.so -lreadline -lncurses /home/jovyan/neuron/nrn-7.4/x86_64/lib/libnrniv.so /home/jovyan/neuron/nrn-7.4/x86_64/lib/libivoc.so /home/jovyan/neuron/nrn-7.4/x86_64/lib/libneuron_gnu.so /home/jovyan/neuron/nrn-7.4/x86_64/lib/libmeschach.so /home/jovyan/neuron/nrn-7.4/x86_64/lib/libsundials.so /home/jovyan/neuron/nrn-7.4/x86_64/lib/libivos.so -lm -ldl  -O2   -pthread -Wl,-soname -Wl,libnrnmech.so.0 -o .libs/libnrnmech.so.0.0.0
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Compile >> > libtool: link: (cd ".libs" && rm -f "libnrnmech.so.0" && ln -s "libnrnmech.so.0.0.0" "libnrnmech.so.0")
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Compile >> > libtool: link: (cd ".libs" && rm -f "libnrnmech.so" && ln -s "libnrnmech.so.0.0.0" "libnrnmech.so")
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Compile >> > libtool: link: ( cd ".libs" && rm -f "libnrnmech.la" && ln -s "../libnrnmech.la" "libnrnmech.la" )
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Compile >> > Successfully created x86_64/special
# pyNeuroML >>>   jNeuroML >>  (INFO) Successful compilation
# pyNeuroML >>>   jNeuroML >>  (INFO) Success: true
# pyNeuroML >>>   jNeuroML >>  (INFO) Have successfully executed command: /home/jovyan/neuron/nrn-7.4/x86_64/bin/nrniv -python /tmp/vanilla_nrn.py
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Error  >>> NEURON -- Release 7.4 (1370:16a7055d4a86) 2015-11-09
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Error  >>> Duke, Yale, and the BlueBrain Project -- Copyright 1984-2015
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Error  >>> See http://www.neuron.yale.edu/neuron/credits
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Error  >>>
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Error  >>> Additional mechanisms from files
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Error  >>>  RS.mod RS_Iext.mod
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Output >>>
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Output >>>     Starting simulation in NEURON generated from NeuroML2 model...
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Output >>>
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Output >>> Population RS_pop contains 1 instance(s) of component: RS of type: izhikevich2007Cell
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Output >>> Running a simulation of 520.0ms (dt = 0.001ms)
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Output >>> Finished NEURON simulation in 0.745500 seconds (0.012425 mins)...
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Output >>> Saving results at t=519.9999999911596...
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Output >>> Saved data to: time.dat
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Output >>> Saved data to: exIzh.dat
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Output >>> Finished saving results in 1.064824 seconds
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Output >>> Done
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Output >>> first instance of n_RS_pop
# pyNeuroML >>>   jNeuroML >>  (INFO) Exit value for running NEURON: 0
# pyNeuroML >>>   jNeuroML >>
# t
# RS_pop[0]/v
# [-0.06       -0.05997393 -0.05994873 ..., -0.04908001 -0.04906528
#  -0.04905055] V
# Injected 2520.0 pA current and got 161 spikes
# pyNeuroML >>> Executing: (java -Xmx400M  -Djava.awt.headless=true -jar  "/opt/conda/lib/python3.5/site-packages/pyneuroml/lib/jNeuroML-0.8.0-jar-with-dependencies.jar"  "/tmp/vanilla.xml"  -neuron -run -nogui) in directory: .
# pyNeuroML >>> Command completed. Output:
# pyNeuroML >>>   jNeuroML >>   jNeuroML v0.8.0
# pyNeuroML >>>   jNeuroML >>  (INFO) Reading from: /tmp/vanilla.xml
# pyNeuroML >>>   jNeuroML >>  (INFO) Creating NeuronWriter for vanilla_nrn.py
# pyNeuroML >>>   jNeuroML >>  (INFO) Adding simulation Component(id=sim1 type=Simulation) of network/component: net1 (Type: network)
# pyNeuroML >>>   jNeuroML >>  (INFO) Adding population: RS_pop
# pyNeuroML >>>   jNeuroML >>  (INFO) -- Writing to mod: /tmp/RS.mod
# pyNeuroML >>>   jNeuroML >>  (INFO) File /tmp/RS.mod exists and is identical
# pyNeuroML >>>   jNeuroML >>  (INFO) Adding projections/connections...
# pyNeuroML >>>   jNeuroML >>  (INFO) -- Writing to mod: /tmp/RS_Iext.mod
# pyNeuroML >>>   jNeuroML >>  (INFO) File /tmp/RS_Iext.mod exists but is different
# pyNeuroML >>>   jNeuroML >>  (INFO) Trying to compile mods in: /tmp
# pyNeuroML >>>   jNeuroML >>  (INFO) Going to compile the mod files in: /tmp, forcing recompile: false
# pyNeuroML >>>   jNeuroML >>  (INFO) Parent dir: /tmp
# pyNeuroML >>>   jNeuroML >>  (INFO) Assuming *nix environment...
# pyNeuroML >>>   jNeuroML >>  (INFO) Name of file to be created: /tmp/x86_64/libnrnmech.la
# pyNeuroML >>>   jNeuroML >>  (INFO) Backup file to check for success: /tmp/x86_64/libnrnmech.la
# pyNeuroML >>>   jNeuroML >>  (INFO) commandToExecute: /home/jovyan/neuron/nrn-7.4/x86_64/bin/nrnivmodl
# pyNeuroML >>>   jNeuroML >>  (INFO) Going to check if mods in /tmp are newer than /tmp/x86_64/libnrnmech.la
# pyNeuroML >>>   jNeuroML >>  (INFO) File /tmp/RS_Iext.mod (November 29, 2016 1:28:01 AM UTC) was modified later than /tmp/x86_64/libnrnmech.la (November 29, 2016 1:27:57 AM UTC)
# pyNeuroML >>>   jNeuroML >>  (INFO) Newer mod files exist!
# pyNeuroML >>>   jNeuroML >>  (INFO) Trying to delete any previous: /tmp/x86_64/libnrnmech.la
# pyNeuroML >>>   jNeuroML >>  (INFO) Deleted.
# pyNeuroML >>>   jNeuroML >>  (INFO) directoryToExecuteIn: /tmp
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Compile >> > /tmp
# pyNeuroML >>>   jNeuroML >>  (INFO) Have successfully executed command: /home/jovyan/neuron/nrn-7.4/x86_64/bin/nrnivmodl
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Compile >> > RS.mod RS_Iext.mod
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Compile >> > RS.mod RS_Iext.mod
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Compile >> > "/home/jovyan/neuron/nrn-7.4/x86_64/bin/nocmodl" RS_Iext
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Error   >> > Translating RS_Iext.mod into RS_Iext.c
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Error   >> > Thread Safe
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Compile >> > "/home/jovyan/neuron/nrn-7.4/share/nrn/libtool"  --mode=compile gcc -DHAVE_CONFIG_H  -I. -I.. -I"/home/jovyan/neuron/nrn-7.4/include/nrn" -I"/home/jovyan/neuron/nrn-7.4/x86_64/lib"      -g -O2 -c -o RS_Iext.lo `test -f 'RS_Iext.c' || echo '/'`RS_Iext.c
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Compile >> > libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I.. -I/home/jovyan/neuron/nrn-7.4/include/nrn -I/home/jovyan/neuron/nrn-7.4/x86_64/lib -g -O2 -c RS_Iext.c  -fPIC -DPIC -o .libs/RS_Iext.o
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Compile >> > "/home/jovyan/neuron/nrn-7.4/share/nrn/libtool"  --mode=compile gcc -DHAVE_CONFIG_H  -I. -I.. -I"/home/jovyan/neuron/nrn-7.4/include/nrn" -I"/home/jovyan/neuron/nrn-7.4/x86_64/lib"      -g -O2 -c -o mod_func.lo mod_func.c
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Compile >> > libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I.. -I/home/jovyan/neuron/nrn-7.4/include/nrn -I/home/jovyan/neuron/nrn-7.4/x86_64/lib -g -O2 -c mod_func.c  -fPIC -DPIC -o .libs/mod_func.o
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Compile >> > "/home/jovyan/neuron/nrn-7.4/share/nrn/libtool"  --mode=link gcc -module  -g -O2    -o libnrnmech.la -rpath "/home/jovyan/neuron/nrn-7.4/x86_64/lib"  RS.lo RS_Iext.lo mod_func.lo  -L"/home/jovyan/neuron/nrn-7.4/x86_64/lib" -lnrnoc -loc -lmemacs -lnrnmpi -lscopmath -lsparse13 -lreadline -lncurses -L"/home/jovyan/neuron/nrn-7.4/x86_64/lib" "/home/jovyan/neuron/nrn-7.4/x86_64/lib/libnrniv.la" -livoc -lneuron_gnu -lmeschach -lsundials -livos      -lm -ldl
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Compile >> > libtool: link: rm -fr  .libs/libnrnmech.la .libs/libnrnmech.lai .libs/libnrnmech.so .libs/libnrnmech.so.0 .libs/libnrnmech.so.0.0.0
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Compile >> > libtool: link: gcc -shared  -fPIC -DPIC  .libs/RS.o .libs/RS_Iext.o .libs/mod_func.o   -Wl,-rpath -Wl,/home/jovyan/neuron/nrn-7.4/x86_64/lib -Wl,-rpath -Wl,/home/jovyan/neuron/nrn-7.4/x86_64/lib -L/home/jovyan/neuron/nrn-7.4/x86_64/lib /home/jovyan/neuron/nrn-7.4/x86_64/lib/libnrnoc.so /home/jovyan/neuron/nrn-7.4/x86_64/lib/liboc.so /home/jovyan/neuron/nrn-7.4/x86_64/lib/libmemacs.so /home/jovyan/neuron/nrn-7.4/x86_64/lib/libnrnmpi.so /home/jovyan/neuron/nrn-7.4/x86_64/lib/libscopmath.so /home/jovyan/neuron/nrn-7.4/x86_64/lib/libsparse13.so -lreadline -lncurses /home/jovyan/neuron/nrn-7.4/x86_64/lib/libnrniv.so /home/jovyan/neuron/nrn-7.4/x86_64/lib/libivoc.so /home/jovyan/neuron/nrn-7.4/x86_64/lib/libneuron_gnu.so /home/jovyan/neuron/nrn-7.4/x86_64/lib/libmeschach.so /home/jovyan/neuron/nrn-7.4/x86_64/lib/libsundials.so /home/jovyan/neuron/nrn-7.4/x86_64/lib/libivos.so -lm -ldl  -O2   -pthread -Wl,-soname -Wl,libnrnmech.so.0 -o .libs/libnrnmech.so.0.0.0
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Compile >> > libtool: link: (cd ".libs" && rm -f "libnrnmech.so.0" && ln -s "libnrnmech.so.0.0.0" "libnrnmech.so.0")
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Compile >> > libtool: link: (cd ".libs" && rm -f "libnrnmech.so" && ln -s "libnrnmech.so.0.0.0" "libnrnmech.so")
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Compile >> > libtool: link: ( cd ".libs" && rm -f "libnrnmech.la" && ln -s "../libnrnmech.la" "libnrnmech.la" )
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Compile >> > Successfully created x86_64/special
# pyNeuroML >>>   jNeuroML >>  (INFO) Successful compilation
# pyNeuroML >>>   jNeuroML >>  (INFO) Success: true
# pyNeuroML >>>   jNeuroML >>  (INFO) Have successfully executed command: /home/jovyan/neuron/nrn-7.4/x86_64/bin/nrniv -python /tmp/vanilla_nrn.py
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Error  >>> NEURON -- Release 7.4 (1370:16a7055d4a86) 2015-11-09
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Error  >>> Duke, Yale, and the BlueBrain Project -- Copyright 1984-2015
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Error  >>> See http://www.neuron.yale.edu/neuron/credits
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Error  >>>
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Error  >>> Additional mechanisms from files
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Error  >>>  RS.mod RS_Iext.mod
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Output >>>
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Output >>>     Starting simulation in NEURON generated from NeuroML2 model...
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Output >>>
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Output >>> Population RS_pop contains 1 instance(s) of component: RS of type: izhikevich2007Cell
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Output >>> Running a simulation of 520.0ms (dt = 0.001ms)
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Output >>> Finished NEURON simulation in 1.042802 seconds (0.017380 mins)...
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Output >>> Saving results at t=519.9999999911596...
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Output >>> Saved data to: time.dat
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Output >>> Saved data to: exIzh.dat
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Output >>> Finished saving results in 1.094023 seconds
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Output >>> Done
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Output >>> first instance of n_RS_pop
# pyNeuroML >>>   jNeuroML >>  (INFO) Exit value for running NEURON: 0
# pyNeuroML >>>   jNeuroML >>
# t
# RS_pop[0]/v
# [-0.06       -0.05998652 -0.05997393 ..., -0.02585358 -0.02584269
#  -0.0258318 ] V
# Injected 1260.0 pA current and got 93 spikes
# pyNeuroML >>> Executing: (java -Xmx400M  -Djava.awt.headless=true -jar  "/opt/conda/lib/python3.5/site-packages/pyneuroml/lib/jNeuroML-0.8.0-jar-with-dependencies.jar"  "/tmp/vanilla.xml"  -neuron -run -nogui) in directory: .
# pyNeuroML >>> Command completed. Output:
# pyNeuroML >>>   jNeuroML >>   jNeuroML v0.8.0
# pyNeuroML >>>   jNeuroML >>  (INFO) Reading from: /tmp/vanilla.xml
# pyNeuroML >>>   jNeuroML >>  (INFO) Creating NeuronWriter for vanilla_nrn.py
# pyNeuroML >>>   jNeuroML >>  (INFO) Adding simulation Component(id=sim1 type=Simulation) of network/component: net1 (Type: network)
# pyNeuroML >>>   jNeuroML >>  (INFO) Adding population: RS_pop
# pyNeuroML >>>   jNeuroML >>  (INFO) -- Writing to mod: /tmp/RS.mod
# pyNeuroML >>>   jNeuroML >>  (INFO) File /tmp/RS.mod exists and is identical
# pyNeuroML >>>   jNeuroML >>  (INFO) Adding projections/connections...
# pyNeuroML >>>   jNeuroML >>  (INFO) -- Writing to mod: /tmp/RS_Iext.mod
# pyNeuroML >>>   jNeuroML >>  (INFO) File /tmp/RS_Iext.mod exists but is different
# pyNeuroML >>>   jNeuroML >>  (INFO) Trying to compile mods in: /tmp
# pyNeuroML >>>   jNeuroML >>  (INFO) Going to compile the mod files in: /tmp, forcing recompile: false
# pyNeuroML >>>   jNeuroML >>  (INFO) Parent dir: /tmp
# pyNeuroML >>>   jNeuroML >>  (INFO) Assuming *nix environment...
# pyNeuroML >>>   jNeuroML >>  (INFO) Name of file to be created: /tmp/x86_64/libnrnmech.la
# pyNeuroML >>>   jNeuroML >>  (INFO) Backup file to check for success: /tmp/x86_64/libnrnmech.la
# pyNeuroML >>>   jNeuroML >>  (INFO) commandToExecute: /home/jovyan/neuron/nrn-7.4/x86_64/bin/nrnivmodl
# pyNeuroML >>>   jNeuroML >>  (INFO) Going to check if mods in /tmp are newer than /tmp/x86_64/libnrnmech.la
# pyNeuroML >>>   jNeuroML >>  (INFO) File /tmp/RS_Iext.mod (November 29, 2016 1:28:05 AM UTC) was modified later than /tmp/x86_64/libnrnmech.la (November 29, 2016 1:28:01 AM UTC)
# pyNeuroML >>>   jNeuroML >>  (INFO) Newer mod files exist!
# pyNeuroML >>>   jNeuroML >>  (INFO) Trying to delete any previous: /tmp/x86_64/libnrnmech.la
# pyNeuroML >>>   jNeuroML >>  (INFO) Deleted.
# pyNeuroML >>>   jNeuroML >>  (INFO) directoryToExecuteIn: /tmp
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Compile >> > /tmp
# pyNeuroML >>>   jNeuroML >>  (INFO) Have successfully executed command: /home/jovyan/neuron/nrn-7.4/x86_64/bin/nrnivmodl
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Compile >> > RS.mod RS_Iext.mod
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Compile >> > RS.mod RS_Iext.mod
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Compile >> > "/home/jovyan/neuron/nrn-7.4/x86_64/bin/nocmodl" RS_Iext
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Error   >> > Translating RS_Iext.mod into RS_Iext.c
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Error   >> > Thread Safe
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Compile >> > "/home/jovyan/neuron/nrn-7.4/share/nrn/libtool"  --mode=compile gcc -DHAVE_CONFIG_H  -I. -I.. -I"/home/jovyan/neuron/nrn-7.4/include/nrn" -I"/home/jovyan/neuron/nrn-7.4/x86_64/lib"      -g -O2 -c -o RS_Iext.lo `test -f 'RS_Iext.c' || echo '/'`RS_Iext.c
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Compile >> > libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I.. -I/home/jovyan/neuron/nrn-7.4/include/nrn -I/home/jovyan/neuron/nrn-7.4/x86_64/lib -g -O2 -c RS_Iext.c  -fPIC -DPIC -o .libs/RS_Iext.o
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Compile >> > "/home/jovyan/neuron/nrn-7.4/share/nrn/libtool"  --mode=compile gcc -DHAVE_CONFIG_H  -I. -I.. -I"/home/jovyan/neuron/nrn-7.4/include/nrn" -I"/home/jovyan/neuron/nrn-7.4/x86_64/lib"      -g -O2 -c -o mod_func.lo mod_func.c
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Compile >> > libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I.. -I/home/jovyan/neuron/nrn-7.4/include/nrn -I/home/jovyan/neuron/nrn-7.4/x86_64/lib -g -O2 -c mod_func.c  -fPIC -DPIC -o .libs/mod_func.o
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Compile >> > "/home/jovyan/neuron/nrn-7.4/share/nrn/libtool"  --mode=link gcc -module  -g -O2    -o libnrnmech.la -rpath "/home/jovyan/neuron/nrn-7.4/x86_64/lib"  RS.lo RS_Iext.lo mod_func.lo  -L"/home/jovyan/neuron/nrn-7.4/x86_64/lib" -lnrnoc -loc -lmemacs -lnrnmpi -lscopmath -lsparse13 -lreadline -lncurses -L"/home/jovyan/neuron/nrn-7.4/x86_64/lib" "/home/jovyan/neuron/nrn-7.4/x86_64/lib/libnrniv.la" -livoc -lneuron_gnu -lmeschach -lsundials -livos      -lm -ldl
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Compile >> > libtool: link: rm -fr  .libs/libnrnmech.la .libs/libnrnmech.lai .libs/libnrnmech.so .libs/libnrnmech.so.0 .libs/libnrnmech.so.0.0.0
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Compile >> > libtool: link: gcc -shared  -fPIC -DPIC  .libs/RS.o .libs/RS_Iext.o .libs/mod_func.o   -Wl,-rpath -Wl,/home/jovyan/neuron/nrn-7.4/x86_64/lib -Wl,-rpath -Wl,/home/jovyan/neuron/nrn-7.4/x86_64/lib -L/home/jovyan/neuron/nrn-7.4/x86_64/lib /home/jovyan/neuron/nrn-7.4/x86_64/lib/libnrnoc.so /home/jovyan/neuron/nrn-7.4/x86_64/lib/liboc.so /home/jovyan/neuron/nrn-7.4/x86_64/lib/libmemacs.so /home/jovyan/neuron/nrn-7.4/x86_64/lib/libnrnmpi.so /home/jovyan/neuron/nrn-7.4/x86_64/lib/libscopmath.so /home/jovyan/neuron/nrn-7.4/x86_64/lib/libsparse13.so -lreadline -lncurses /home/jovyan/neuron/nrn-7.4/x86_64/lib/libnrniv.so /home/jovyan/neuron/nrn-7.4/x86_64/lib/libivoc.so /home/jovyan/neuron/nrn-7.4/x86_64/lib/libneuron_gnu.so /home/jovyan/neuron/nrn-7.4/x86_64/lib/libmeschach.so /home/jovyan/neuron/nrn-7.4/x86_64/lib/libsundials.so /home/jovyan/neuron/nrn-7.4/x86_64/lib/libivos.so -lm -ldl  -O2   -pthread -Wl,-soname -Wl,libnrnmech.so.0 -o .libs/libnrnmech.so.0.0.0
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Compile >> > libtool: link: (cd ".libs" && rm -f "libnrnmech.so.0" && ln -s "libnrnmech.so.0.0.0" "libnrnmech.so.0")
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Compile >> > libtool: link: (cd ".libs" && rm -f "libnrnmech.so" && ln -s "libnrnmech.so.0.0.0" "libnrnmech.so")
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Compile >> > libtool: link: ( cd ".libs" && rm -f "libnrnmech.la" && ln -s "../libnrnmech.la" "libnrnmech.la" )
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Compile >> > Successfully created x86_64/special
# pyNeuroML >>>   jNeuroML >>  (INFO) Successful compilation
# pyNeuroML >>>   jNeuroML >>  (INFO) Success: true
# pyNeuroML >>>   jNeuroML >>  (INFO) Have successfully executed command: /home/jovyan/neuron/nrn-7.4/x86_64/bin/nrniv -python /tmp/vanilla_nrn.py
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Error  >>> NEURON -- Release 7.4 (1370:16a7055d4a86) 2015-11-09
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Error  >>> Duke, Yale, and the BlueBrain Project -- Copyright 1984-2015
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Error  >>> See http://www.neuron.yale.edu/neuron/credits
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Error  >>>
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Error  >>> Additional mechanisms from files
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Error  >>>  RS.mod RS_Iext.mod
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Output >>>
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Output >>>     Starting simulation in NEURON generated from NeuroML2 model...
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Output >>>
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Output >>> Population RS_pop contains 1 instance(s) of component: RS of type: izhikevich2007Cell
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Output >>> Running a simulation of 520.0ms (dt = 0.001ms)
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Output >>> Finished NEURON simulation in 0.696593 seconds (0.011610 mins)...
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Output >>> Saving results at t=519.9999999911596...
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Output >>> Saved data to: time.dat
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Output >>> Saved data to: exIzh.dat
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Output >>> Finished saving results in 1.117599 seconds
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Output >>> Done
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Output >>> first instance of n_RS_pop
# pyNeuroML >>>   jNeuroML >>  (INFO) Exit value for running NEURON: 0
# pyNeuroML >>>   jNeuroML >>
# t
# RS_pop[0]/v
# [-0.06       -0.05999282 -0.05998653 ..., -0.04395011 -0.04394728
#  -0.04394445] V
# Injected 630.0 pA current and got 54 spikes
# pyNeuroML >>> Executing: (java -Xmx400M  -Djava.awt.headless=true -jar  "/opt/conda/lib/python3.5/site-packages/pyneuroml/lib/jNeuroML-0.8.0-jar-with-dependencies.jar"  "/tmp/vanilla.xml"  -neuron -run -nogui) in directory: .
# pyNeuroML >>> Command completed. Output:
# pyNeuroML >>>   jNeuroML >>   jNeuroML v0.8.0
# pyNeuroML >>>   jNeuroML >>  (INFO) Reading from: /tmp/vanilla.xml
# pyNeuroML >>>   jNeuroML >>  (INFO) Creating NeuronWriter for vanilla_nrn.py
# pyNeuroML >>>   jNeuroML >>  (INFO) Adding simulation Component(id=sim1 type=Simulation) of network/component: net1 (Type: network)
# pyNeuroML >>>   jNeuroML >>  (INFO) Adding population: RS_pop
# pyNeuroML >>>   jNeuroML >>  (INFO) -- Writing to mod: /tmp/RS.mod
# pyNeuroML >>>   jNeuroML >>  (INFO) File /tmp/RS.mod exists and is identical
# pyNeuroML >>>   jNeuroML >>  (INFO) Adding projections/connections...
# pyNeuroML >>>   jNeuroML >>  (INFO) -- Writing to mod: /tmp/RS_Iext.mod
# pyNeuroML >>>   jNeuroML >>  (INFO) File /tmp/RS_Iext.mod exists but is different
# pyNeuroML >>>   jNeuroML >>  (INFO) Trying to compile mods in: /tmp
# pyNeuroML >>>   jNeuroML >>  (INFO) Going to compile the mod files in: /tmp, forcing recompile: false
# pyNeuroML >>>   jNeuroML >>  (INFO) Parent dir: /tmp
# pyNeuroML >>>   jNeuroML >>  (INFO) Assuming *nix environment...
# pyNeuroML >>>   jNeuroML >>  (INFO) Name of file to be created: /tmp/x86_64/libnrnmech.la
# pyNeuroML >>>   jNeuroML >>  (INFO) Backup file to check for success: /tmp/x86_64/libnrnmech.la
# pyNeuroML >>>   jNeuroML >>  (INFO) commandToExecute: /home/jovyan/neuron/nrn-7.4/x86_64/bin/nrnivmodl
# pyNeuroML >>>   jNeuroML >>  (INFO) Going to check if mods in /tmp are newer than /tmp/x86_64/libnrnmech.la
# pyNeuroML >>>   jNeuroML >>  (INFO) File /tmp/RS_Iext.mod (November 29, 2016 1:28:08 AM UTC) was modified later than /tmp/x86_64/libnrnmech.la (November 29, 2016 1:28:05 AM UTC)
# pyNeuroML >>>   jNeuroML >>  (INFO) Newer mod files exist!
# pyNeuroML >>>   jNeuroML >>  (INFO) Trying to delete any previous: /tmp/x86_64/libnrnmech.la
# pyNeuroML >>>   jNeuroML >>  (INFO) Deleted.
# pyNeuroML >>>   jNeuroML >>  (INFO) directoryToExecuteIn: /tmp
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Compile >> > /tmp
# pyNeuroML >>>   jNeuroML >>  (INFO) Have successfully executed command: /home/jovyan/neuron/nrn-7.4/x86_64/bin/nrnivmodl
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Compile >> > RS.mod RS_Iext.mod
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Compile >> > RS.mod RS_Iext.mod
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Compile >> > "/home/jovyan/neuron/nrn-7.4/x86_64/bin/nocmodl" RS_Iext
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Error   >> > Translating RS_Iext.mod into RS_Iext.c
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Error   >> > Thread Safe
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Compile >> > "/home/jovyan/neuron/nrn-7.4/share/nrn/libtool"  --mode=compile gcc -DHAVE_CONFIG_H  -I. -I.. -I"/home/jovyan/neuron/nrn-7.4/include/nrn" -I"/home/jovyan/neuron/nrn-7.4/x86_64/lib"      -g -O2 -c -o RS_Iext.lo `test -f 'RS_Iext.c' || echo '/'`RS_Iext.c
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Compile >> > libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I.. -I/home/jovyan/neuron/nrn-7.4/include/nrn -I/home/jovyan/neuron/nrn-7.4/x86_64/lib -g -O2 -c RS_Iext.c  -fPIC -DPIC -o .libs/RS_Iext.o
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Compile >> > "/home/jovyan/neuron/nrn-7.4/share/nrn/libtool"  --mode=compile gcc -DHAVE_CONFIG_H  -I. -I.. -I"/home/jovyan/neuron/nrn-7.4/include/nrn" -I"/home/jovyan/neuron/nrn-7.4/x86_64/lib"      -g -O2 -c -o mod_func.lo mod_func.c
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Compile >> > libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I.. -I/home/jovyan/neuron/nrn-7.4/include/nrn -I/home/jovyan/neuron/nrn-7.4/x86_64/lib -g -O2 -c mod_func.c  -fPIC -DPIC -o .libs/mod_func.o
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Compile >> > "/home/jovyan/neuron/nrn-7.4/share/nrn/libtool"  --mode=link gcc -module  -g -O2    -o libnrnmech.la -rpath "/home/jovyan/neuron/nrn-7.4/x86_64/lib"  RS.lo RS_Iext.lo mod_func.lo  -L"/home/jovyan/neuron/nrn-7.4/x86_64/lib" -lnrnoc -loc -lmemacs -lnrnmpi -lscopmath -lsparse13 -lreadline -lncurses -L"/home/jovyan/neuron/nrn-7.4/x86_64/lib" "/home/jovyan/neuron/nrn-7.4/x86_64/lib/libnrniv.la" -livoc -lneuron_gnu -lmeschach -lsundials -livos      -lm -ldl
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Compile >> > libtool: link: rm -fr  .libs/libnrnmech.la .libs/libnrnmech.lai .libs/libnrnmech.so .libs/libnrnmech.so.0 .libs/libnrnmech.so.0.0.0
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Compile >> > libtool: link: gcc -shared  -fPIC -DPIC  .libs/RS.o .libs/RS_Iext.o .libs/mod_func.o   -Wl,-rpath -Wl,/home/jovyan/neuron/nrn-7.4/x86_64/lib -Wl,-rpath -Wl,/home/jovyan/neuron/nrn-7.4/x86_64/lib -L/home/jovyan/neuron/nrn-7.4/x86_64/lib /home/jovyan/neuron/nrn-7.4/x86_64/lib/libnrnoc.so /home/jovyan/neuron/nrn-7.4/x86_64/lib/liboc.so /home/jovyan/neuron/nrn-7.4/x86_64/lib/libmemacs.so /home/jovyan/neuron/nrn-7.4/x86_64/lib/libnrnmpi.so /home/jovyan/neuron/nrn-7.4/x86_64/lib/libscopmath.so /home/jovyan/neuron/nrn-7.4/x86_64/lib/libsparse13.so -lreadline -lncurses /home/jovyan/neuron/nrn-7.4/x86_64/lib/libnrniv.so /home/jovyan/neuron/nrn-7.4/x86_64/lib/libivoc.so /home/jovyan/neuron/nrn-7.4/x86_64/lib/libneuron_gnu.so /home/jovyan/neuron/nrn-7.4/x86_64/lib/libmeschach.so /home/jovyan/neuron/nrn-7.4/x86_64/lib/libsundials.so /home/jovyan/neuron/nrn-7.4/x86_64/lib/libivos.so -lm -ldl  -O2   -pthread -Wl,-soname -Wl,libnrnmech.so.0 -o .libs/libnrnmech.so.0.0.0
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Compile >> > libtool: link: (cd ".libs" && rm -f "libnrnmech.so.0" && ln -s "libnrnmech.so.0.0.0" "libnrnmech.so.0")
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Compile >> > libtool: link: (cd ".libs" && rm -f "libnrnmech.so" && ln -s "libnrnmech.so.0.0.0" "libnrnmech.so")
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Compile >> > libtool: link: ( cd ".libs" && rm -f "libnrnmech.la" && ln -s "../libnrnmech.la" "libnrnmech.la" )
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Compile >> > Successfully created x86_64/special
# pyNeuroML >>>   jNeuroML >>  (INFO) Successful compilation
# pyNeuroML >>>   jNeuroML >>  (INFO) Success: true
# pyNeuroML >>>   jNeuroML >>  (INFO) Have successfully executed command: /home/jovyan/neuron/nrn-7.4/x86_64/bin/nrniv -python /tmp/vanilla_nrn.py
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Error  >>> NEURON -- Release 7.4 (1370:16a7055d4a86) 2015-11-09
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Error  >>> Duke, Yale, and the BlueBrain Project -- Copyright 1984-2015
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Error  >>> See http://www.neuron.yale.edu/neuron/credits
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Error  >>>
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Error  >>> Additional mechanisms from files
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Error  >>>  RS.mod RS_Iext.mod
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Output >>>
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Output >>>     Starting simulation in NEURON generated from NeuroML2 model...
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Output >>>
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Output >>> Population RS_pop contains 1 instance(s) of component: RS of type: izhikevich2007Cell
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Output >>> Running a simulation of 520.0ms (dt = 0.001ms)
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Output >>> Finished NEURON simulation in 0.794569 seconds (0.013243 mins)...
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Output >>> Saving results at t=519.9999999911596...
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Output >>> Saved data to: time.dat
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Output >>> Saved data to: exIzh.dat
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Output >>> Finished saving results in 1.107799 seconds
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Output >>> Done
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Output >>> first instance of n_RS_pop
# pyNeuroML >>>   jNeuroML >>  (INFO) Exit value for running NEURON: 0
# pyNeuroML >>>   jNeuroML >>
# t
# RS_pop[0]/v
# [-0.06       -0.05999597 -0.05999283 ...,  0.01703862  0.01707163
#   0.01710467] V
# Injected 315.0 pA current and got 30 spikes
# pyNeuroML >>> Executing: (java -Xmx400M  -Djava.awt.headless=true -jar  "/opt/conda/lib/python3.5/site-packages/pyneuroml/lib/jNeuroML-0.8.0-jar-with-dependencies.jar"  "/tmp/vanilla.xml"  -neuron -run -nogui) in directory: .
# pyNeuroML >>> Command completed. Output:
# pyNeuroML >>>   jNeuroML >>   jNeuroML v0.8.0
# pyNeuroML >>>   jNeuroML >>  (INFO) Reading from: /tmp/vanilla.xml
# pyNeuroML >>>   jNeuroML >>  (INFO) Creating NeuronWriter for vanilla_nrn.py
# pyNeuroML >>>   jNeuroML >>  (INFO) Adding simulation Component(id=sim1 type=Simulation) of network/component: net1 (Type: network)
# pyNeuroML >>>   jNeuroML >>  (INFO) Adding population: RS_pop
# pyNeuroML >>>   jNeuroML >>  (INFO) -- Writing to mod: /tmp/RS.mod
# pyNeuroML >>>   jNeuroML >>  (INFO) File /tmp/RS.mod exists and is identical
# pyNeuroML >>>   jNeuroML >>  (INFO) Adding projections/connections...
# pyNeuroML >>>   jNeuroML >>  (INFO) -- Writing to mod: /tmp/RS_Iext.mod
# pyNeuroML >>>   jNeuroML >>  (INFO) File /tmp/RS_Iext.mod exists but is different
# pyNeuroML >>>   jNeuroML >>  (INFO) Trying to compile mods in: /tmp
# pyNeuroML >>>   jNeuroML >>  (INFO) Going to compile the mod files in: /tmp, forcing recompile: false
# pyNeuroML >>>   jNeuroML >>  (INFO) Parent dir: /tmp
# pyNeuroML >>>   jNeuroML >>  (INFO) Assuming *nix environment...
# pyNeuroML >>>   jNeuroML >>  (INFO) Name of file to be created: /tmp/x86_64/libnrnmech.la
# pyNeuroML >>>   jNeuroML >>  (INFO) Backup file to check for success: /tmp/x86_64/libnrnmech.la
# pyNeuroML >>>   jNeuroML >>  (INFO) commandToExecute: /home/jovyan/neuron/nrn-7.4/x86_64/bin/nrnivmodl
# pyNeuroML >>>   jNeuroML >>  (INFO) Going to check if mods in /tmp are newer than /tmp/x86_64/libnrnmech.la
# pyNeuroML >>>   jNeuroML >>  (INFO) File /tmp/RS_Iext.mod (November 29, 2016 1:28:12 AM UTC) was modified later than /tmp/x86_64/libnrnmech.la (November 29, 2016 1:28:08 AM UTC)
# pyNeuroML >>>   jNeuroML >>  (INFO) Newer mod files exist!
# pyNeuroML >>>   jNeuroML >>  (INFO) Trying to delete any previous: /tmp/x86_64/libnrnmech.la
# pyNeuroML >>>   jNeuroML >>  (INFO) Deleted.
# pyNeuroML >>>   jNeuroML >>  (INFO) directoryToExecuteIn: /tmp
# pyNeuroML >>>   jNeuroML >>  (INFO) Have successfully executed command: /home/jovyan/neuron/nrn-7.4/x86_64/bin/nrnivmodl
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Compile >> > /tmp
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Compile >> > RS.mod RS_Iext.mod
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Compile >> > RS.mod RS_Iext.mod
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Compile >> > "/home/jovyan/neuron/nrn-7.4/x86_64/bin/nocmodl" RS_Iext
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Error   >> > Translating RS_Iext.mod into RS_Iext.c
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Error   >> > Thread Safe
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Compile >> > "/home/jovyan/neuron/nrn-7.4/share/nrn/libtool"  --mode=compile gcc -DHAVE_CONFIG_H  -I. -I.. -I"/home/jovyan/neuron/nrn-7.4/include/nrn" -I"/home/jovyan/neuron/nrn-7.4/x86_64/lib"      -g -O2 -c -o RS_Iext.lo `test -f 'RS_Iext.c' || echo '/'`RS_Iext.c
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Compile >> > libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I.. -I/home/jovyan/neuron/nrn-7.4/include/nrn -I/home/jovyan/neuron/nrn-7.4/x86_64/lib -g -O2 -c RS_Iext.c  -fPIC -DPIC -o .libs/RS_Iext.o
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Compile >> > "/home/jovyan/neuron/nrn-7.4/share/nrn/libtool"  --mode=compile gcc -DHAVE_CONFIG_H  -I. -I.. -I"/home/jovyan/neuron/nrn-7.4/include/nrn" -I"/home/jovyan/neuron/nrn-7.4/x86_64/lib"      -g -O2 -c -o mod_func.lo mod_func.c
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Compile >> > libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I.. -I/home/jovyan/neuron/nrn-7.4/include/nrn -I/home/jovyan/neuron/nrn-7.4/x86_64/lib -g -O2 -c mod_func.c  -fPIC -DPIC -o .libs/mod_func.o
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Compile >> > "/home/jovyan/neuron/nrn-7.4/share/nrn/libtool"  --mode=link gcc -module  -g -O2    -o libnrnmech.la -rpath "/home/jovyan/neuron/nrn-7.4/x86_64/lib"  RS.lo RS_Iext.lo mod_func.lo  -L"/home/jovyan/neuron/nrn-7.4/x86_64/lib" -lnrnoc -loc -lmemacs -lnrnmpi -lscopmath -lsparse13 -lreadline -lncurses -L"/home/jovyan/neuron/nrn-7.4/x86_64/lib" "/home/jovyan/neuron/nrn-7.4/x86_64/lib/libnrniv.la" -livoc -lneuron_gnu -lmeschach -lsundials -livos      -lm -ldl
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Compile >> > libtool: link: rm -fr  .libs/libnrnmech.la .libs/libnrnmech.lai .libs/libnrnmech.so .libs/libnrnmech.so.0 .libs/libnrnmech.so.0.0.0
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Compile >> > libtool: link: gcc -shared  -fPIC -DPIC  .libs/RS.o .libs/RS_Iext.o .libs/mod_func.o   -Wl,-rpath -Wl,/home/jovyan/neuron/nrn-7.4/x86_64/lib -Wl,-rpath -Wl,/home/jovyan/neuron/nrn-7.4/x86_64/lib -L/home/jovyan/neuron/nrn-7.4/x86_64/lib /home/jovyan/neuron/nrn-7.4/x86_64/lib/libnrnoc.so /home/jovyan/neuron/nrn-7.4/x86_64/lib/liboc.so /home/jovyan/neuron/nrn-7.4/x86_64/lib/libmemacs.so /home/jovyan/neuron/nrn-7.4/x86_64/lib/libnrnmpi.so /home/jovyan/neuron/nrn-7.4/x86_64/lib/libscopmath.so /home/jovyan/neuron/nrn-7.4/x86_64/lib/libsparse13.so -lreadline -lncurses /home/jovyan/neuron/nrn-7.4/x86_64/lib/libnrniv.so /home/jovyan/neuron/nrn-7.4/x86_64/lib/libivoc.so /home/jovyan/neuron/nrn-7.4/x86_64/lib/libneuron_gnu.so /home/jovyan/neuron/nrn-7.4/x86_64/lib/libmeschach.so /home/jovyan/neuron/nrn-7.4/x86_64/lib/libsundials.so /home/jovyan/neuron/nrn-7.4/x86_64/lib/libivos.so -lm -ldl  -O2   -pthread -Wl,-soname -Wl,libnrnmech.so.0 -o .libs/libnrnmech.so.0.0.0
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Compile >> > libtool: link: (cd ".libs" && rm -f "libnrnmech.so.0" && ln -s "libnrnmech.so.0.0.0" "libnrnmech.so.0")
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Compile >> > libtool: link: (cd ".libs" && rm -f "libnrnmech.so" && ln -s "libnrnmech.so.0.0.0" "libnrnmech.so")
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Compile >> > libtool: link: ( cd ".libs" && rm -f "libnrnmech.la" && ln -s "../libnrnmech.la" "libnrnmech.la" )
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Compile >> > Successfully created x86_64/special
# pyNeuroML >>>   jNeuroML >>  (INFO) Successful compilation
# pyNeuroML >>>   jNeuroML >>  (INFO) Success: true
# pyNeuroML >>>   jNeuroML >>  (INFO) Have successfully executed command: /home/jovyan/neuron/nrn-7.4/x86_64/bin/nrniv -python /tmp/vanilla_nrn.py
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Error  >>> NEURON -- Release 7.4 (1370:16a7055d4a86) 2015-11-09
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Error  >>> Duke, Yale, and the BlueBrain Project -- Copyright 1984-2015
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Error  >>> See http://www.neuron.yale.edu/neuron/credits
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Error  >>>
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Error  >>> Additional mechanisms from files
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Error  >>>  RS.mod RS_Iext.mod
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Output >>>
# ...
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Compile >> > "/home/jovyan/neuron/nrn-7.4/share/nrn/libtool"  --mode=link gcc -module  -g -O2    -o libnrnmech.la -rpath "/home/jovyan/neuron/nrn-7.4/x86_64/lib"  RS.lo RS_Iext.lo mod_func.lo  -L"/home/jovyan/neuron/nrn-7.4/x86_64/lib" -lnrnoc -loc -lmemacs -lnrnmpi -lscopmath -lsparse13 -lreadline -lncurses -L"/home/jovyan/neuron/nrn-7.4/x86_64/lib" "/home/jovyan/neuron/nrn-7.4/x86_64/lib/libnrniv.la" -livoc -lneuron_gnu -lmeschach -lsundials -livos      -lm -ldl
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Compile >> > libtool: link: rm -fr  .libs/libnrnmech.la .libs/libnrnmech.lai .libs/libnrnmech.so .libs/libnrnmech.so.0 .libs/libnrnmech.so.0.0.0
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Compile >> > libtool: link: gcc -shared  -fPIC -DPIC  .libs/RS.o .libs/RS_Iext.o .libs/mod_func.o   -Wl,-rpath -Wl,/home/jovyan/neuron/nrn-7.4/x86_64/lib -Wl,-rpath -Wl,/home/jovyan/neuron/nrn-7.4/x86_64/lib -L/home/jovyan/neuron/nrn-7.4/x86_64/lib /home/jovyan/neuron/nrn-7.4/x86_64/lib/libnrnoc.so /home/jovyan/neuron/nrn-7.4/x86_64/lib/liboc.so /home/jovyan/neuron/nrn-7.4/x86_64/lib/libmemacs.so /home/jovyan/neuron/nrn-7.4/x86_64/lib/libnrnmpi.so /home/jovyan/neuron/nrn-7.4/x86_64/lib/libscopmath.so /home/jovyan/neuron/nrn-7.4/x86_64/lib/libsparse13.so -lreadline -lncurses /home/jovyan/neuron/nrn-7.4/x86_64/lib/libnrniv.so /home/jovyan/neuron/nrn-7.4/x86_64/lib/libivoc.so /home/jovyan/neuron/nrn-7.4/x86_64/lib/libneuron_gnu.so /home/jovyan/neuron/nrn-7.4/x86_64/lib/libmeschach.so /home/jovyan/neuron/nrn-7.4/x86_64/lib/libsundials.so /home/jovyan/neuron/nrn-7.4/x86_64/lib/libivos.so -lm -ldl  -O2   -pthread -Wl,-soname -Wl,libnrnmech.so.0 -o .libs/libnrnmech.so.0.0.0
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Compile >> > libtool: link: (cd ".libs" && rm -f "libnrnmech.so.0" && ln -s "libnrnmech.so.0.0.0" "libnrnmech.so.0")
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Compile >> > libtool: link: (cd ".libs" && rm -f "libnrnmech.so" && ln -s "libnrnmech.so.0.0.0" "libnrnmech.so")
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Compile >> > libtool: link: ( cd ".libs" && rm -f "libnrnmech.la" && ln -s "../libnrnmech.la" "libnrnmech.la" )
# pyNeuroML >>>   jNeuroML >>  (INFO) Successful compilation
# pyNeuroML >>>   jNeuroML >>  (INFO) Success: true
# pyNeuroML >>>   jNeuroML >>  (INFO) NMODL Compile >> > Successfully created x86_64/special
# pyNeuroML >>>   jNeuroML >>  (INFO) Have successfully executed command: /home/jovyan/neuron/nrn-7.4/x86_64/bin/nrniv -python /tmp/vanilla_nrn.py
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Error  >>> NEURON -- Release 7.4 (1370:16a7055d4a86) 2015-11-09
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Error  >>> Duke, Yale, and the BlueBrain Project -- Copyright 1984-2015
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Error  >>> See http://www.neuron.yale.edu/neuron/credits
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Error  >>>
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Error  >>> Additional mechanisms from files
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Error  >>>  RS.mod RS_Iext.mod
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Output >>>
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Output >>>     Starting simulation in NEURON generated from NeuroML2 model...
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Output >>>
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Output >>> Population RS_pop contains 1 instance(s) of component: RS of type: izhikevich2007Cell
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Output >>> Running a simulation of 520.0ms (dt = 0.001ms)
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Output >>> Finished NEURON simulation in 0.878533 seconds (0.014642 mins)...
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Output >>> Saving results at t=519.9999999911596...
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Output >>> Saved data to: time.dat
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Output >>> Saved data to: exIzh.dat
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Output >>> Finished saving results in 1.379635 seconds
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Output >>> Done
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Output >>> first instance of n_RS_pop
# pyNeuroML >>>   jNeuroML >>  (INFO) Exit value for running NEURON: 0
# pyNeuroML >>>   jNeuroML >>
# t
# RS_pop[0]/v
# [-0.06       -0.05999913 -0.05999913 ..., -0.0540178  -0.05401777
#  -0.05401774] V
# pyNeuroML >>> Executing: (java -Xmx400M  -Djava.awt.headless=true -jar  "/opt/conda/lib/python3.5/site-packages/pyneuroml/lib/jNeuroML-0.8.0-jar-with-dependencies.jar"  "/tmp/vanilla.xml"  -neuron -run -nogui) in directory: .
# /opt/conda/lib/python3.5/site-packages/numpy/core/_methods.py:59: RuntimeWarning: Mean of empty slice.
#   warnings.warn("Mean of empty slice.", RuntimeWarning)
# /opt/conda/lib/python3.5/site-packages/numpy/core/_methods.py:70: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# pyNeuroML >>> Command completed. Output:
# pyNeuroML >>>   jNeuroML >>   jNeuroML v0.8.0
# pyNeuroML >>>   jNeuroML >>  (INFO) Reading from: /tmp/vanilla.xml
# pyNeuroML >>>   jNeuroML >>  (INFO) Creating NeuronWriter for vanilla_nrn.py
# pyNeuroML >>>   jNeuroML >>  (INFO) Adding simulation Component(id=sim1 type=Simulation) of network/component: net1 (Type: network)
# pyNeuroML >>>   jNeuroML >>  (INFO) Adding population: RS_pop
# pyNeuroML >>>   jNeuroML >>  (INFO) -- Writing to mod: /tmp/RS.mod
# pyNeuroML >>>   jNeuroML >>  (INFO) File /tmp/RS.mod exists and is identical
# pyNeuroML >>>   jNeuroML >>  (INFO) Adding projections/connections...
# pyNeuroML >>>   jNeuroML >>  (INFO) -- Writing to mod: /tmp/RS_Iext.mod
# pyNeuroML >>>   jNeuroML >>  (INFO) File /tmp/RS_Iext.mod exists and is identical
# pyNeuroML >>>   jNeuroML >>  (INFO) Trying to compile mods in: /tmp
# pyNeuroML >>>   jNeuroML >>  (INFO) Going to compile the mod files in: /tmp, forcing recompile: false
# pyNeuroML >>>   jNeuroML >>  (INFO) Parent dir: /tmp
# pyNeuroML >>>   jNeuroML >>  (INFO) Assuming *nix environment...
# pyNeuroML >>>   jNeuroML >>  (INFO) Name of file to be created: /tmp/x86_64/libnrnmech.la
# pyNeuroML >>>   jNeuroML >>  (INFO) Backup file to check for success: /tmp/x86_64/libnrnmech.la
# pyNeuroML >>>   jNeuroML >>  (INFO) commandToExecute: /home/jovyan/neuron/nrn-7.4/x86_64/bin/nrnivmodl
# pyNeuroML >>>   jNeuroML >>  (INFO) Going to check if mods in /tmp are newer than /tmp/x86_64/libnrnmech.la
# pyNeuroML >>>   jNeuroML >>  (INFO) Not being asked to recompile, and no mod files exist in /tmp which are newer than /tmp/x86_64/libnrnmech.la
# pyNeuroML >>>   jNeuroML >>  (INFO) Success: true
# pyNeuroML >>>   jNeuroML >>  (INFO) Have successfully executed command: /home/jovyan/neuron/nrn-7.4/x86_64/bin/nrniv -python /tmp/vanilla_nrn.py
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Error  >>> NEURON -- Release 7.4 (1370:16a7055d4a86) 2015-11-09
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Error  >>> Duke, Yale, and the BlueBrain Project -- Copyright 1984-2015
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Error  >>> See http://www.neuron.yale.edu/neuron/credits
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Error  >>>
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Error  >>> Additional mechanisms from files
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Error  >>>  RS.mod RS_Iext.mod
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Output >>>
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Output >>>     Starting simulation in NEURON generated from NeuroML2 model...
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Output >>>
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Output >>> Population RS_pop contains 1 instance(s) of component: RS of type: izhikevich2007Cell
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Output >>> Running a simulation of 520.0ms (dt = 0.001ms)
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Output >>> Finished NEURON simulation in 0.835881 seconds (0.013931 mins)...
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Output >>> Saving results at t=519.9999999911596...
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Output >>> Saved data to: time.dat
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Output >>> Saved data to: exIzh.dat
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Output >>> Finished saving results in 1.135308 seconds
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Output >>> Done
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Output >>> first instance of n_RS_pop
# pyNeuroML >>>   jNeuroML >>  (INFO) Exit value for running NEURON: 0
# pyNeuroML >>>   jNeuroML >>
# t
# RS_pop[0]/v
# [-0.06       -0.05999913 -0.05999913 ..., -0.0540178  -0.05401777
#  -0.05401774] V
# Score is <a style="color: rgb(128,128,128)">Z = nan</a>
# Executing test <i>TimeConstantTest</i> on model <i>vanilla</i>...
# pyNeuroML >>> Executing: (java -Xmx400M  -Djava.awt.headless=true -jar  "/opt/conda/lib/python3.5/site-packages/pyneuroml/lib/jNeuroML-0.8.0-jar-with-dependencies.jar"  "/tmp/vanilla.xml"  -neuron -run -nogui) in directory: .
# pyNeuroML >>> Command completed. Output:
# pyNeuroML >>>   jNeuroML >>   jNeuroML v0.8.0
# pyNeuroML >>>   jNeuroML >>  (INFO) Reading from: /tmp/vanilla.xml
# pyNeuroML >>>   jNeuroML >>  (INFO) Creating NeuronWriter for vanilla_nrn.py
# pyNeuroML >>>   jNeuroML >>  (INFO) Adding simulation Component(id=sim1 type=Simulation) of network/component: net1 (Type: network)
# pyNeuroML >>>   jNeuroML >>  (INFO) Adding population: RS_pop
# pyNeuroML >>>   jNeuroML >>  (INFO) -- Writing to mod: /tmp/RS.mod
# pyNeuroML >>>   jNeuroML >>  (INFO) File /tmp/RS.mod exists and is identical
# pyNeuroML >>>   jNeuroML >>  (INFO) Adding projections/connections...
# pyNeuroML >>>   jNeuroML >>  (INFO) -- Writing to mod: /tmp/RS_Iext.mod
# pyNeuroML >>>   jNeuroML >>  (INFO) File /tmp/RS_Iext.mod exists and is identical
# pyNeuroML >>>   jNeuroML >>  (INFO) Trying to compile mods in: /tmp
# pyNeuroML >>>   jNeuroML >>  (INFO) Going to compile the mod files in: /tmp, forcing recompile: false
# pyNeuroML >>>   jNeuroML >>  (INFO) Parent dir: /tmp
# pyNeuroML >>>   jNeuroML >>  (INFO) Assuming *nix environment...
# pyNeuroML >>>   jNeuroML >>  (INFO) Name of file to be created: /tmp/x86_64/libnrnmech.la
# pyNeuroML >>>   jNeuroML >>  (INFO) Backup file to check for success: /tmp/x86_64/libnrnmech.la
# pyNeuroML >>>   jNeuroML >>  (INFO) commandToExecute: /home/jovyan/neuron/nrn-7.4/x86_64/bin/nrnivmodl
# pyNeuroML >>>   jNeuroML >>  (INFO) Going to check if mods in /tmp are newer than /tmp/x86_64/libnrnmech.la
# pyNeuroML >>>   jNeuroML >>  (INFO) Not being asked to recompile, and no mod files exist in /tmp which are newer than /tmp/x86_64/libnrnmech.la
# pyNeuroML >>>   jNeuroML >>  (INFO) Success: true
# pyNeuroML >>>   jNeuroML >>  (INFO) Have successfully executed command: /home/jovyan/neuron/nrn-7.4/x86_64/bin/nrniv -python /tmp/vanilla_nrn.py
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Error  >>> NEURON -- Release 7.4 (1370:16a7055d4a86) 2015-11-09
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Error  >>> Duke, Yale, and the BlueBrain Project -- Copyright 1984-2015
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Error  >>> See http://www.neuron.yale.edu/neuron/credits
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Error  >>>
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Error  >>> Additional mechanisms from files
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Error  >>>  RS.mod RS_Iext.mod
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Output >>>
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Output >>>     Starting simulation in NEURON generated from NeuroML2 model...
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Output >>>
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Output >>> Population RS_pop contains 1 instance(s) of component: RS of type: izhikevich2007Cell
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Output >>> Running a simulation of 520.0ms (dt = 0.001ms)
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Output >>> Finished NEURON simulation in 0.864298 seconds (0.014405 mins)...
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Output >>> Saving results at t=519.9999999911596...
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Output >>> Saved data to: time.dat
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Output >>> Saved data to: exIzh.dat
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Output >>> Finished saving results in 1.274062 seconds
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Output >>> Done
# pyNeuroML >>>   jNeuroML >>  (INFO) NRN Output >>> first instance of n_RS_pop
# pyNeuroML >>>   jNeuroML >>  (INFO) Exit value for running NEURON: 0
# pyNeuroML >>>   jNeuroML >>
# t
# RS_pop[0]/v
# [-0.06       -0.05999913 -0.05999913 ..., -0.0540178  -0.05401777
#  -0.05401774] V
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-21-2a2bb450b800> in <module>()
#       1 model = ReducedModel(LEMS_MODEL_PATH,name='vanilla')
# ----> 2 suite.judge(model)
#
# /opt/conda/lib/python3.5/site-packages/sciunit/__init__.py in judge(self, models, skip_incapable, stop_on_error, deep_error)
#     428                 score = test.judge(model, skip_incapable=skip_incapable,
#     429                                           stop_on_error=stop_on_error,
# --> 430                                           deep_error=deep_error)
#     431                 log('Score is <a style="color: rgb(%d,%d,%d)">' % score.color()
#     432                   + '%s</a>' % score)
#
# /opt/conda/lib/python3.5/site-packages/sciunit/__init__.py in judge(self, model, skip_incapable, stop_on_error, deep_error)
#     300                 score = ErrorScore(e)
#     301         if isinstance(score,ErrorScore) and stop_on_error:
# --> 302             raise score.score # An exception.
#     303         return score
#     304
#
# /opt/conda/lib/python3.5/site-packages/sciunit/__init__.py in judge(self, model, skip_incapable, stop_on_error, deep_error)
#     294         else:
#     295             try:
# --> 296                 score = self._judge(model, skip_incapable=skip_incapable)
#     297             except CapabilityError as e:
#     298                 score = NAScore(str(e))
#
# /opt/conda/lib/python3.5/site-packages/sciunit/__init__.py in _judge(self, model, skip_incapable)
#     237         self.check_capabilities(model)
#     238         # 2.
# --> 239         prediction = self.generate_prediction(model)
#     240         self.last_model = model
#     241         # 3.
#
# /opt/conda/lib/python3.5/site-packages/neuronunit/tests/__init__.py in generate_prediction(self, model)
#     213         """Implementation of sciunit.Test.generate_prediction."""
#     214         i,vm = super(TimeConstantTest,self).generate_prediction(model)
# --> 215         tau = self.__class__.get_tau(vm, i)
#     216         tau = tau.simplified
#     217         # Put prediction in a form that compute_score() can use.
#
# /opt/conda/lib/python3.5/site-packages/neuronunit/tests/__init__.py in get_tau(cls, vm, i)
#     161         start, stop = -11*pq.ms, (i['duration']-(1*pq.ms))
#     162         region = cls.get_segment(vm,start+i['delay'],stop+i['delay'])
# --> 163         coefs = cls.exponential_fit(region, i['delay'])
#     164         tau = (pq.s/coefs[1]).rescale('ms')
#     165         return tau
#
# /opt/conda/lib/python3.5/site-packages/neuronunit/tests/__init__.py in exponential_fit(cls, segment, offset)
#     173         y = segment.rescale('V')
#     174         offset = float(offset.rescale('s')) # Strip units for optimization
# --> 175         popt, pcov = curve_fit(func, x-offset*pq.s, y, [0.001,2,y.min()]) # Estimate starting values for better convergence
#     176         return popt
#     177
#
# /opt/conda/lib/python3.5/site-packages/scipy/optimize/minpack.py in curve_fit(f, xdata, ydata, p0, sigma, absolute_sigma, check_finite, bounds, method, jac, **kwargs)
#     678         cost = np.sum(infodict['fvec'] ** 2)
#     679         if ier not in [1, 2, 3, 4]:
# --> 680             raise RuntimeError("Optimal parameters not found: " + errmsg)
#     681     else:
#     682         res = least_squares(func, p0, jac=jac, bounds=bounds, method=method,
#
# RuntimeError: Optimal parameters not found: Number of calls to function has reached maxfev = 800.

# %%
test = nu_tests.TimeConstantTest

# %%
models = []
for vr in np.linspace(-75,-50,6):
    model = ReducedModel(LEMS_MODEL_PATH, 
                         name='V_rest=%dmV' % vr, 
                         attrs={'//izhikevich2007Cell':
                                    {'vr':'%d mV' % vr}
                               })
    #model.skip_run = True
    models.append(model)
score_matrix = suite.judge(models, verbose=False)
score_matrix.show_mean = True
score_matrix.sortable = True
score_matrix

# %%
from neo.core import AnalogSignal
x = AnalogSignal([1,2,3],units='mV',sampling_period=0.001*pq.s)
np.array(x)

# %%
import matplotlib as mpl
mpl.rcParams['font.size'] = 20
vm = score_matrix[tests[3]][4].related_data['vm'].rescale('mV') # Plot the rheobase current (test 3) 
                                                                # from v_rest = -55 mV (model 4)
ax = plt.gca()
ax.plot(vm.times,vm)
y_min = float(vm.min()-5.0*pq.mV)
y_max = float(vm.max()+5.0*pq.mV)
ax.set_xlim(0,1.6)
ax.set_ylim(y_min,y_max)
ax.set_xlabel('Time (s)',size=24)
ax.set_ylabel('Vm (mV)',size=24);
plt.tight_layout()

# %%
"""
for a in np.linspace(0.015,0.045,2):
    for b in np.linspace(-3.5,-0.5,2):
        for C in np.linspace(50,150,3):
            for k in np.linspace(0.4,1.0,3):
                model = ReducedModel(LEMS_MODEL_PATH, 
                             name='a=%.3fperms_b=%.1fnS_C=%dpF_k=%.2f' % (a,b,C,k), 
                             attrs={'//izhikevich2007Cell':
                                        {'b':'%.1f nS' % b,
                                         'a':'%.3f per_ms' % a,
                                         'C':'%d pF' % C,
                                         'k':'%.2f nS_per_mV' % k,
                                         'vr':'-68 mV',
                                         'vpeak':'45 mV'}
                                   })
                #model.skip_run = True
                models3.append(model)
score_matrix3 = suite.judge(models3, verbose=False)
score_matrix3.show_mean = True
score_matrix3.sortable = True
score_matrix3
""";

# %%
"""
models2 = []
for i,a in enumerate(np.linspace(0.015,0.045,7)):
    for j,b in enumerate(np.linspace(-3.5,-0.5,7)):
        model = ReducedModel(LEMS_MODEL_PATH, 
                     name='a=%.3fperms_b=%.1fnS' % (a,b), 
                     attrs={'//izhikevich2007Cell':
                                {'b':'%.1f nS' % b,
                                 'a':'%.3f per_ms' % a,
                                 'C':'150 pF',
                                 'k':'0.70 nS_per_mV',
                                 'vr':'-68 mV',
                                 'vpeak':'45 mV'}
                           })
        #model.skip_run = True
        models2.append(model)
score_matrix2 = suite.judge(models2, verbose=False)
score_matrix2.show_mean = True
score_matrix2.sortable = True
score_matrix2
""";

# %%
"""
import matplotlib as mpl
mpl.rcParams['font.size'] = 18
heatmap = np.zeros((7,7))
for i,a in enumerate(np.linspace(0.015,0.045,7)):
    for j,b in enumerate(np.linspace(-3.5,-0.5,7)):
        for model in score_matrix2.models:
            if model.name == 'a=%.3fperms_b=%.1fnS' % (a,b):
                heatmap[i,j] = 20*(score_matrix2[model].mean() - 0.8070)+0.8070#[tests[0]].score
#heatmap[2,0] = np.nan
plt.pcolor(heatmap,cmap='magma')
plt.yticks(np.arange(7)+0.5,np.linspace(0.015,0.045,7))
plt.ylabel('Izhikevich Parameter $a$')
plt.xticks(np.arange(7)+0.5,np.linspace(-3.5,-0.5,7))
plt.xlabel('Izhikevich Parameter $b$')
cbar = plt.colorbar()
cbar.set_label('Mean Test Score',size=15)
cbar.ax.tick_params(labelsize=15) 
plt.tight_layout()
np.save('heatmap',heatmap)
""";

# %%
"""
from neuronunit.tests.dynamics import TFRTypeTest,BurstinessTest

is_bursty = BurstinessTest(observation={'cv_mean':1.5, 'cv_std':1.0})
score_matrix2 = is_bursty.judge(models)
score_matrix2
""";

# %%
"""
#rickpy.refresh_objects(locals(),modules=None)
rickpy.refresh_objects(locals().copy(),modules=['sciunit','neuronunit'])
isinstance(tests[0],sciunit.Test) # Should print True if successful
""";
